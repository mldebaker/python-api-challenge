# %% [markdown]
# # __WeatherPy__

# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## __Generate Cities List__

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ## __Perform API Calls__

# %% [markdown]
# ##### * *Perform a weather check on each city using a series of successive API calls.*

# %% [markdown]
# ##### * *Include a print log of each city as it'sbeing processed (with the city number and city name).*

# %%
# Create location for Data 
cities2 = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
# Set API Key, Counters, and URL  
counter_1 = 0
counter_2 = 0
api_key = "4ac328f8885c6f15e2bdfd9e4b95e471"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
# Create loop for API Data Pull
print('---------------------------')
print('Starting Data Retrieval')
print('---------------------------')
for city in cities:
    url2 = url + "&q=" + city
    response = requests.get(url2).json()
    if counter_1 < 50:
        counter_1 += 1
    else:
        counter_2 += 1
        counter_1 = 0
    print('Processing {} of set {} | {}'.format(counter_1, counter_2, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        cities2.append(city)
    except:
        print("City not found!")
        pass
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ---------------------------
# Starting Data Retrieval
# ---------------------------
# Processing 1 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 0 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 3 of set 0 | benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 0 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 5 of set 0 | staunton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 0 | darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 0 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 10 of set 0 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 12 of set 0 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 0 | les cayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 0 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 0 | catalina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 0 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 0 | teknaf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 0 | nekrasovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 0 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 0 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 0 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 0 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 0 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 0 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 0 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 0 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 0 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 0 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 0 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 0 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 0 | biscarrosse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 0 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 42 of set 0 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 0 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 0 | bouloupari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 0 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 0 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 0 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 0 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 0 | wau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 0 of set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 1 | farmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 1 | manzanillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 1 | rockhampton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 1 | berezovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 1 | villamontes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 1 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 1 | jeremie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 1 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 10 of set 1 | la macarena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 1 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 1 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 13 of set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 1 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 1 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 1 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 1 | hue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 1 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 1 | chengde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 1 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 1 | mansa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 1 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 1 | azimur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 27 of set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 1 | boddam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 1 | dire dawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 1 | taikang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 1 | izumo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 1 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 1 | balimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 36 of set 1 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 1 | plouzane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 1 | tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 1 | lingdong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 42 of set 1 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 43 of set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 1 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 1 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 1 | vuktyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 1 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 2 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 2 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 2 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 2 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 2 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 2 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 2 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 10 of set 2 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 2 | zomba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 2 | katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 2 | malabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 2 | imeni poliny osipenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 2 | macapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 2 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 2 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 2 | koslan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 2 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 2 | urgut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 2 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 25 of set 2 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 2 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 2 | kihei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 2 | kazerun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 2 | tazmalt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 2 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 2 | vidim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 2 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 2 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 39 of set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 2 | otane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 2 | doume
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 42 of set 2 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 2 | palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 2 | la primavera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 2 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 48 of set 2 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 2 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 2 | morro bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 3 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 3 | svetlyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 2 of set 3 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 4 of set 3 | altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 3 | yanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 6 of set 3 | kataysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 3 | nauta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 3 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 9 of set 3 | kondinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 10 of set 3 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 3 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 3 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 3 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 14 of set 3 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 3 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 3 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 3 | nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 3 | asayita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 19 of set 3 | sinop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 3 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 3 | pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 3 | bogorodskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 3 | formoso do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 24 of set 3 | kearney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 3 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 3 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 3 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 3 | innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 3 | sao domingos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 3 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 3 | fairlie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 3 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 3 | bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 3 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 3 | wahran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 37 of set 3 | le port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 3 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 3 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 40 of set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 3 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 42 of set 3 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 3 | garoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 3 | lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 3 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 3 | murdochville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 3 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 3 | durban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 3 | evanston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 4 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 4 | senneterre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 4 | yablonovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 4 | adamas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 4 | grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 5 of set 4 | caraguatatuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 4 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 4 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 4 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 10 of set 4 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 4 | kristiansund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 4 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 13 of set 4 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 4 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 4 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 4 | sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 4 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 4 | sosnovo-ozerskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 4 | timberlake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 4 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 4 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 4 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 4 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 4 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 4 | simoes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 4 | sena madureira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 4 | mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 4 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 4 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 4 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 4 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 4 | lilongwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 4 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 4 | kurobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 35 of set 4 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 4 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 4 | jovellar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 4 | sao joao del rei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 4 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 4 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 4 | bokspits
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 42 of set 4 | chibuto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 4 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 4 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 4 | mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 4 | lodi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 4 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 4 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 4 | coxim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 4 | general macarthur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 5 | isiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 5 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 5 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 5 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 5 | barranca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 5 | waw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 6 of set 5 | kaupanger
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 5 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 5 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 5 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 10 of set 5 | gonaives
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 5 | camacupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 5 | tsabong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 5 | warrnambool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 5 | rovereto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 5 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 5 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 5 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 5 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 5 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 20 of set 5 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 5 | biloela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 5 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 5 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 24 of set 5 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 5 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 5 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 27 of set 5 | la asuncion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 5 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 5 | opobo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 30 of set 5 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 5 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 5 | tirumullaivasal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 5 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 5 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 5 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 36 of set 5 | conceicao do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 5 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 5 | sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 5 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 5 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 5 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 42 of set 5 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 5 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 5 | damietta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 5 | svobodnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 5 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 5 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 5 | kapuskasing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 5 | severomuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 6 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 6 | macherla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 6 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 6 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 6 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 6 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 6 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 6 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 8 of set 6 | phalodi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 6 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 10 of set 6 | yuzawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 6 | dutse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 6 | yangjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 6 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 6 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 6 | ermelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 6 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 6 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 6 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 6 | makung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 20 of set 6 | paso de los toros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 6 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 22 of set 6 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 6 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 6 | kortkeros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 6 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 26 of set 6 | khorol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 6 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 6 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 29 of set 6 | odweyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 30 of set 6 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 6 | terrytown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 6 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 6 | fez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 6 | canico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 6 | dehloran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 6 | ust-bolsheretsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 37 of set 6 | mon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 6 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 6 | lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 6 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 6 | amurzet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 42 of set 6 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 6 | sucua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 6 | rongcheng
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 9 | bafra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 9 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 9 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 9 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 9 | shahreza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 9 | kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 9 | gamboma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 9 | waitati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 9 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 9 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 9 | sofiysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 40 of set 9 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 9 | vicosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 42 of set 9 | daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 9 | tupik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 9 | oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 9 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 9 | labytnangi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 9 | sinkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 48 of set 9 | sile
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 9 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 9 | constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 10 | palmas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 10 | dzhusaly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 2 of set 10 | montepuez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 10 | keetmanshoop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 10 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 10 | kadoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 10 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 10 | vung tau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 10 | narendranagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 10 | chikoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 10 of set 10 | coralville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 10 | gewane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 10 | peace river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 10 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 10 | iranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 10 | resavica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 10 | kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 10 | orapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 10 | cape canaveral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 10 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 10 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 10 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 10 | karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 23 of set 10 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 10 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 10 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 10 | gorom-gorom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 10 | san jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 10 | diapaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 10 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 10 | alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 10 | chapleau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 10 | darnah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 10 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 10 | horizontina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 10 | cocoa beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 10 | karatau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 10 | san isidro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 10 | tanout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 10 | cooma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 10 | ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 10 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 42 of set 10 | kalaleh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 10 | ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 44 of set 10 | anshun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 10 | huadian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 10 | dzidzantun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 10 | araguaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 10 | oga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 10 | alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 10 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 11 | kayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 11 | bokoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 2 of set 11 | almeirim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 11 | rosita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 11 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 11 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 11 | beian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 11 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 11 | gambela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 11 | falealupo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 10 of set 11 | la paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 11 | betsiamites
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 11 | sitges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 11 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 11 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 11 | nueva germania
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 11 | yangambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 11 | raga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 18 of set 11 | zheleznodorozhnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 11 | portoferraio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 11 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 11 | america dourada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 11 | manbij
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 11 | doka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 11 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 11 | tingi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 11 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 11 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 11 | hendijan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 29 of set 11 | tosya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 11 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 11 | tahta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 32 of set 11 | loandjili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 11 | bintulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 11 | preston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 11 | snyder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 11 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 11 | chiredzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 11 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 11 | calabozo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 11 | chebarkul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 11 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ##  __Convert Raw Data to DataFrame__

# %% [markdown]
# ##### * *Export the city data into a .csv.*

# %% [markdown]
# ##### * *Display the DataFrame*

# %%
zippedList =  list(zip(cities2, cloudiness, country, date, humidity, temp, lat, lng, wind))
df = pd.DataFrame(zippedList, columns = ['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Temp', 'Lat', 'Lng', 'Wind'])
df.to_csv('weather.csv')
df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity   Temp    Lat     Lng  \
# 0  port hardy          90      CA  1570414241        93  50.00  50.70 -127.42
# 1  port hardy          90      CA  1570414241        93  50.00  50.70 -127.42
# 2  port hardy          90      CA  1570415455        93  50.00  50.70 -127.42
# 3      albany          90      US  1570415731        82  66.20  42.65  -73.75
# 4    benguela         100      AO  1570415963        84  71.78 -12.58   13.40
#
#     Wind
# 0  13.87
# 1  13.87
# 2  13.87
# 3  10.29
# 4   4.76

# %% [markdown]
# # __Plotting the Data__

# %% [markdown]
# ##### * *Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.*

# %% [markdown]
# ##### * *Save the plotted figures as .pngs.*

# %% [markdown]
# # __Latitude vs. Temperature Plot__

# %%
df.plot(kind='scatter', y='Temp', x='Lat')
plt.grid()
plt.title('City Latitude vs. Temperature', fontsize=20)
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# # __Latitude vs. Humidity Plot__

# %%
df.plot(kind='scatter', y='Humidity', x='Lat')
plt.grid()
plt.title('City Latitude vs. Humidity', fontsize=20)
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# # __Latitude vs. Cloudiness Plot__

# %%
df.plot(kind='scatter', y='Cloudiness', x='Lat')
plt.grid()
plt.title('City Latitude vs. Cloudiness', fontsize=20)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# %% [markdown]
# # __Latitude vs. Wind Speed Plot__

# %%
df.plot(kind='scatter', y='Wind', x='Lat')
plt.grid()
plt.title('City Latitude vs. Wind Speed', fontsize=20)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
