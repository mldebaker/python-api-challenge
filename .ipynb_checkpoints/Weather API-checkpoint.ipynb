# %% [markdown]
# # __WeatherPy__

# %% [markdown]
# ### __Analysis__
# ##### Latitude Vs. Tempeture shows that the closer the city is to the equator you get th hotter the tempeture seems to be. Latitude vs. Humididty shows that the closer to the equator the city is to the equator the more likely it will have high humidity. The equator did not seem to place any influence apon cloudiness at all on this day. Wind speed also did not seem to be affected by the equator at all on this day.

# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## __Generate Cities List__

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ## __Perform API Calls__
# ##### * *Perform a weather check on each city using a series of successive API calls.*
# ##### * *Include a print log of each city as it'sbeing processed (with the city number and city name).*

# %%
# Create location for Data 
cities2 = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
# Set API Key, Counters, and URL  
counter_1 = 0
counter_2 = 0
api_key = "4ac328f8885c6f15e2bdfd9e4b95e471"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
# Create loop for API Data Pull
print('---------------------------')
print('Starting Data Retrieval')
print('---------------------------')
for city in cities:
    url2 = url + "&q=" + city
    response = requests.get(url2).json()
    if counter_1 < 50:
        counter_1 += 1
    else:
        counter_2 += 1
        counter_1 = 0
    print('Processing {} of set {} | {}'.format(counter_1, counter_2, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        cities2.append(city)
    except:
        print("City not found!")
        pass
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ---------------------------
# Starting Data Retrieval
# ---------------------------
# Processing 1 of set 0 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 0 | krasnystaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 0 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 4 of set 0 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 0 | huancabamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 0 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 0 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 0 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 0 | leshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 10 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 0 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 0 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 0 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 0 | zachagansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 15 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 0 | vozuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 0 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 0 | wad madani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 21 of set 0 | muscat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 0 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 0 | tramandai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 0 | at-bashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 0 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 0 | felidhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 29 of set 0 | talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 0 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 31 of set 0 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 0 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 0 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 0 | priargunsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 0 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 36 of set 0 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 37 of set 0 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 0 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 0 | la joya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 42 of set 0 | dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 0 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 0 | bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 0 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 0 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 0 | rondonopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 1 | kyshtovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 1 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 1 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 1 | karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 7 of set 1 | alekseyevsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 10 of set 1 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 11 of set 1 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 12 of set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 1 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 1 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 1 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 1 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 1 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 1 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 1 | evansville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 1 | cedar city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 1 | rapid valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 1 | beaverlodge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 1 | semporna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 1 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 1 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 1 | masaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 1 | paracuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 1 | mumbwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 42 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 1 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 44 of set 1 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 1 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 47 of set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 1 | coos bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 1 | stromness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 2 | benjamin constant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 2 | noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 2 | yahotyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 2 | khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 2 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 2 | bainbridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 2 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 2 | rio de janeiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 10 of set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 2 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 2 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 2 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 2 | vagur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 2 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 2 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 2 | ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 2 | sijunjung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 2 | birin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 2 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 2 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 2 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 28 of set 2 | tongchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 2 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 2 | kula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 2 | dondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 2 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 2 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 2 | barawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 35 of set 2 | otradnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 2 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 2 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 2 | sestri levante
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 2 | arambagh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 2 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 42 of set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 2 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 2 | ghanzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 46 of set 2 | juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 2 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 2 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 2 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 50 of set 2 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 3 | bukachacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 3 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 2 of set 3 | lubbock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 3 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 3 | ozgon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 5 of set 3 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 3 | loandjili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 3 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 3 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 9 of set 3 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 10 of set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 3 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 3 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 3 | san rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 3 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 15 of set 3 | saurimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 3 | santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 3 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 19 of set 3 | altamira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 3 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 22 of set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 3 | manono
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 3 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 3 | smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 3 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 3 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 3 | moba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 3 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 3 | statesboro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 31 of set 3 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 3 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 3 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 3 | sahrak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 35 of set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 36 of set 3 | kjopsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 37 of set 3 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 38 of set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 39 of set 3 | berlesti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 40 of set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 41 of set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 42 of set 3 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 43 of set 3 | ryotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 44 of set 3 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 45 of set 3 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 46 of set 3 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 47 of set 3 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 48 of set 3 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 3 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 50 of set 3 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 4 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 1 of set 4 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 4 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 4 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 4 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 4 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 4 | karamea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 7 of set 4 | hattiesburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set
| hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 49 of set 10 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 50 of set 10 | tutoia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 0 of set 11 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 1 of set 11 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 2 of set 11 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 3 of set 11 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 4 of set 11 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 5 of set 11 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 6 of set 11 | klamath falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 7 of set 11 | kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 8 of set 11 | sumbawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 9 of set 11 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 10 of set 11 | hare bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 11 of set 11 | joura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 12 of set 11 | peabiru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 13 of set 11 | kollo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 14 of set 11 | wilmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 15 of set 11 | ilembula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 16 of set 11 | dalbandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 17 of set 11 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 18 of set 11 | ornes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 19 of set 11 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 20 of set 11 | chesma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 21 of set 11 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 22 of set 11 | lano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 23 of set 11 | nivala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 24 of set 11 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 25 of set 11 | ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 26 of set 11 | terra rica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 27 of set 11 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 28 of set 11 | genhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 29 of set 11 | hulyaypole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 30 of set 11 | tukrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# City not found!
# Processing 31 of set 11 | worthington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 32 of set 11 | kamensk-uralskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 33 of set 11 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 34 of set 11 | lannion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# Processing 35 of set 11 | yagodnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ac328f8885c6f15e2bdfd9e4b95e471
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ##  __Convert Raw Data to DataFrame__
# ##### * *Export the city data into a .csv.*
# ##### * *Display the DataFrame*

# %%
zippedList =  list(zip(cities2, cloudiness, country, date, humidity, temp, lat, lng, wind))
df = pd.DataFrame(zippedList, columns = ['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Temp', 'Lat', 'Lng', 'Wind'])
df.to_csv('weather.csv')
df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0     souillac          90      FR  1570493671        87  63.00  45.60
# 1   krasnystaw           0      PL  1570493671        86  33.80  50.98
# 2     takoradi          98      GH  1570493671        91  74.36   4.89
# 3  huancabamba          96      PE  1570493672        82  58.41  -5.24
# 4   codrington          64      AU  1570493672        69  93.20 -28.95
#
#       Lng  Wind
# 0   -0.60  5.82
# 1   23.16  4.70
# 2   -1.75  4.32
# 3  -79.45  3.78
# 4  153.24  8.05

# %% [markdown]
# # __Plotting the Data__
# ##### * *Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.*
# ##### * *Save the plotted figures as .pngs.*

# %% [markdown]
# # __Latitude vs. Temperature Plot__

# %%
df.plot(kind='scatter', y='Temp', x='Lat')
plt.grid()
plt.title('City Latitude vs. Temperature', fontsize=20)
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.savefig('lat_temp.png')
plt.show()

# %% [markdown]
# # __Latitude vs. Humidity Plot__

# %%
df.plot(kind='scatter', y='Humidity', x='Lat')
plt.grid()
plt.title('City Latitude vs. Humidity', fontsize=20)
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.savefig('lat_humidity.png')
plt.show()

# %% [markdown]
# # __Latitude vs. Cloudiness Plot__

# %%
df.plot(kind='scatter', y='Cloudiness', x='Lat')
plt.grid()
plt.title('City Latitude vs. Cloudiness', fontsize=20)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('lat_cloudiness.png')
plt.show()

# %% [markdown]
# # __Latitude vs. Wind Speed Plot__

# %%
df.plot(kind='scatter', y='Wind', x='Lat')
plt.grid()
plt.title('City Latitude vs. Wind Speed', fontsize=20)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('lat_Wind.png')
plt.show()
